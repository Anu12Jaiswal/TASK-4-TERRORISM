# %%
#ANURADHA JAISWAL
#THE SPARKS FOUNDATION 
#GRIP-MAY23

# %%
import pandas as pd 
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
terr=pd.read_csv('/content/drive/MyDrive/globalterrorismdb_0718dist.csv',encoding='ISO-8859-1')
# Out:
# <ipython-input-13-6b4a600a142d>:1: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   terr=pd.read_csv('/content/drive/MyDrive/globalterrorismdb_0718dist.csv',encoding='ISO-8859-1')

# %%
terr.head(10)
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
# 5  197001010002   1970       1     1        NaN         0        NaN      217
# 6  197001020001   1970       1     2        NaN         0        NaN      218
# 7  197001020002   1970       1     2        NaN         0        NaN      217
# 8  197001020003   1970       1     2        NaN         0        NaN      217
# 9  197001030001   1970       1     3        NaN         0        NaN      217
#
#           country_txt  region  ...  \
# 0  Dominican Republic       2  ...
# 1              Mexico       1  ...
# ...

# %%
terr.tail(7)
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181684  201712310019   2017      12    31        NaN         0        NaN
# 181685  201712310020   2017      12    31        NaN         0        NaN
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181684       92        India       6  ...      NaN
# 181685        4  Afghanistan       6  ...      NaN
# 181686      182      Somalia      11  ...      NaN
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# ...

# %%
terr.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
data.dtypes
# Out:
# eventid        int64
# iyear          int64
# imonth         int64
# iday           int64
# approxdate    object
#                ...
# INT_LOG        int64
# INT_IDEO       int64
# INT_MISC       int64
# INT_ANY        int64
# related       object
# Length: 135, dtype: object

# %%
terr.dropna(inplace=True)

# %%
df = terr[['iyear', 'imonth', 'country_txt', 'region_txt', 'city', 'success', 'attacktype1_txt', 'weaptype1_txt', 'targtype1_txt', 'nkill', 'nwound']]

# %%
#df['date'] = pd.to_datetime(data[['iyear', 'imonth']].assign(iday=1))

# %%
data.describe()
# Out:
#                iyear         imonth        success          nkill  \
# count  181691.000000  181691.000000  181691.000000  171378.000000
# mean     2002.638997       6.467277       0.889598       2.403272
# std        13.259430       3.388303       0.313391      11.545741
# min      1970.000000       0.000000       0.000000       0.000000
# 25%      1991.000000       4.000000       1.000000       0.000000
# 50%      2009.000000       6.000000       1.000000       0.000000
# 75%      2014.000000       9.000000       1.000000       2.000000
# max      2017.000000      12.000000       1.000000    1570.000000
#
#               nwound
# count  165380.000000
# mean        3.167668
# std        35.949392
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         2.000000
# max      8191.000000

# %%
plt.figure(figsize=(12, 6))
data['iyear'].value_counts().sort_index().plot(kind='bar')
plt.xlabel('Year')
plt.ylabel('Number of Attacks')
plt.title('Number of Terrorist Attacks per Year')
plt.show()

# %%
plt.figure(figsize=(8, 8))
data['attacktype1_txt'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Distribution of Attack Types')
plt.show()

# %%
#Distribution of Fatalities by Attack Type 
plt.figure(figsize=(12, 6))
data.boxplot(column='nkill', by='attacktype1_txt')
plt.xlabel('Attack Type')
plt.ylabel('Number of Kills')
plt.title('Distribution of Fatalities by Attack Type')
plt.xticks(rotation=90)
plt.show()

# %%
# Distribution of Attack Types by Region
cross_tab = pd.crosstab(data['region_txt'], data['attacktype1_txt'])
cross_tab.plot(kind='bar', stacked=True, figsize=(12, 6))
plt.xlabel('Region')
plt.ylabel('Number of Attacks')
plt.title('Distribution of Attack Types by Region')
plt.legend(title='Attack Type')
plt.show()

# %%
#Number of Attacks by Country
plt.figure(figsize=(12, 6))
data['country_txt'].value_counts().head(10).plot(kind='bar')
plt.xlabel('Country')
plt.ylabel('Number of Attacks')
plt.title('Top 10 Countries with Highest Number of Attacks')
plt.show()

# %%
plt.figure(figsize=(8, 8))
data['targtype1_txt'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Distribution of Target Types')
plt.show()

# %%
#THANKYOU //
